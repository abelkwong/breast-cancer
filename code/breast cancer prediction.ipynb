# %% [markdown]
# ## Installation

# %%
pip install pycaret[full]
# Out:
# ...
#   Using cached mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
# ...
#   Using cached pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# ...
#   Using cached explainerdashboard-0.3.8.2-py3-none-any.whl (305 kB)
# ...
#   Using cached mlflow-1.30.0-py3-none-any.whl (17.0 MB)
# ...
#   Using cached umap_learn-0.5.3-py3-none-any.whl
# ...
#   Using cached shap-0.41.0-cp37-cp37m-macosx_10_9_x86_64.whl (436 kB)
# ...
#   Using cached ray-2.3.0-cp37-cp37m-macosx_10_15_intel.whl (78.2 MB)
# ...
#   Using cached comet_ml-3.32.3-py3-none-any.whl (469 kB)
# ...
#   Using cached Flask-2.2.3-py3-none-any.whl (101 kB)
# ...
#   Using cached deepchecks-0.12.0-py3-none-any.whl (7.7 MB)
# ...
#   Using cached fastapi-0.93.0-py3-none-any.whl (56 kB)
# ...
#   Using cached uvicorn-0.20.0-py3-none-any.whl (56 kB)
# ...
#   Using cached m2cgen-0.10.0-py3-none-any.whl (92 kB)
# ...
#   Using cached scikit_learn_intelex-2023.0.2-py37-none-macosx_10_15_x86_64.macosx_11_0_x86_64.whl (83 kB)
# ...
#   Using cached hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
# ...

# %% [markdown]
# ## Import Libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from pycaret.classification import *

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('data 2.csv')
display(df.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Drop id column
df.drop('id', axis=1, inplace=True)
display(df.head())
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
# Drop null values
df.drop('Unnamed: 32', axis=1, inplace=True)
display(df.head())
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Dataframe dimensions
df.shape
# Out:
# (569, 33)

# %%
# Counts of benign and malignant 
df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# #### Distribution plots

# %%
features = df.columns[~df.columns.isin(['diagnosis'])]

def get_distribution_plots(features, df):
    for feature in features:
        sns.displot(df[feature])
        plt.show()
        
get_distribution_plots(features, df)

# %% [markdown]
# #### Correlation matrix

# %%
corr = df.corr()

sns.heatmap(corr)
sn
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocess Data

# %% [markdown]
# #### Feature and target variables

# %%
X = df.iloc[:,1:]
y = df.iloc[:,0]

# %% [markdown]
# **Transform target variable**

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y)

df['diagnosis'] = le.transform(y)
y = df.iloc[:,0]
df['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## Model Building

# %% [markdown]
# #### Split into train/test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# #### Setup model

# %%
train_df = pd.concat([X_train, y_train], axis=1)
s = setup(data=train_df, target='diagnosis')
# Out:
# <style type="text/css">
# #T_9fee4_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9fee4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fee4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fee4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9fee4_row0_col1" class="data row0 col1" >7866</td>
#     </tr>
#     <tr>
#       <th id="T_9fee4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9fee4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9fee4_row1_col1" class="data row1 col1" >diagnosis</td>
#     </tr>
#     <tr>
#       <th id="T_9fee4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9fee4_row2_col0" class="data row2 col0" >Target type</td>
# ...

# %% [markdown]
# #### Compare models

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_673fd_ th {
#   text-align: left;
# }
# ...

# %% [markdown]
# #### Create model

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_320e7_row10_col0, #T_320e7_row10_col1, #T_320e7_row10_col2, #T_320e7_row10_col3, #T_320e7_row10_col4, #T_320e7_row10_col5, #T_320e7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_320e7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %% [markdown]
# ## Tune Model

# %%
tuned_lr = tune_model(lr)
# Out:
# <style type="text/css">
# #T_5cf5c_row10_col0, #T_5cf5c_row10_col1, #T_5cf5c_row10_col2, #T_5cf5c_row10_col3, #T_5cf5c_row10_col4, #T_5cf5c_row10_col5, #T_5cf5c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5cf5c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %% [markdown]
# ## Predictions

# %% [markdown]
# #### Scores and predicted values

# %%
preds = predict_model(lr)
# Out:
# <style type="text/css">
# </style>
# <table id="T_877f0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_877f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_877f0_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_877f0_row0_col1" class="data row0 col1" >0.9416</td>
#       <td id="T_877f0_row0_col2" class="data row0 col2" >0.9950</td>
#       <td id="T_877f0_row0_col3" class="data row0 col3" >0.9608</td>
# ...

# %%
preds
# Out:
#      radius_mean  texture_mean  perimeter_mean    area_mean  smoothness_mean  \
# 318     8.196000     16.840000       51.709999   201.899994          0.08600
# 319    14.860000     16.940001       94.889999   673.700012          0.08924
# 320    12.830000     22.330000       85.260002   503.200012          0.10880
# 321    13.400000     16.950001       85.480003   552.400024          0.07937
# 322    12.880000     28.920000       82.500000   514.299988          0.08123
# ..           ...           ...             ...          ...              ...
# 450     8.726000     15.830000       55.840000   230.899994          0.11500
# 451    17.290001     22.129999      114.400002   947.799988          0.08999
# 452    25.730000     17.459999      174.199997  2010.000000          0.11490
# 453    13.200000     15.820000       84.070000   537.299988          0.08511
# 454    13.400000     20.520000       88.639999   556.700012          0.11060
#
# ...

# %% [markdown]
# #### AUC-ROC curve

# %%
plot_model(lr)

# %% [markdown]
# #### Error plot

# %%
plot_model(lr, plot='error')
